# %% [markdown]
# ## Notas del PS
#
# No tuve en cuenta que la regresión lasso tiene que ser dentro del loop, habiendo ya elegido las ponderaciones, por covarianzas. De todos modos, no estoy muy segura de si estoy de acuerdo con omo define el exposure igual...
#
# ![image.png](attachment:image.png)
#
# despues mejoro el typing
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# kick off de lionel: notar que estamos concentrando en 2 activos de 5 y eso es lo que mas logra diversificar

# %% [markdown]
# ## TEORICA
#
# ### Support vector machine regression
#
# Tiene una loss fucntion que dentro de un canal (e tube) es indiferente.
#
# Aca los datos se transfroman con la funcion h o kernel
#
# ![image.png](attachment:image.png)
#
# ### REGRESSION TREE
#
# suelen hacer mucho overfitting
