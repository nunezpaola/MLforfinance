# %% [markdown]
# ## Notas del tp
#
# 1. No le parece una buena idea sacar el fondo con retorno negativo porque no es un outlier
# 2. lo que si hizo es 'ortogonalizar' el retorno de los últimos 6 meses sacandole el retorno de los últimos 3 meses
# 3. Ademas escala la volatilidad de mensual a trimestral
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# (mira el primer quiebre)
#
# ja, me dió horrible a mi.
#
# 4. No le parece buena idea estandarizar de hecho. Porque rompés la media y volatilidad propias de cada serie. Y al escalar perdés esa información.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# pyportfolioopt

# %% [markdown]
# ### Clase: "El problema de representación"
#
# ![image.png](attachment:image.png)
#
#
# Con redes neuronales hay que tener variables demeaned pero no estandarizadas
#
# ![image-2.png](attachment:image-2.png)
#
# Ver link clase sobre cuando estandarizar
#
#
# ![image-3.png](attachment:image-3.png)
#
# Hasta que punto simplifico?
#
# ![image-4.png](attachment:image-4.png)
#
# sobre pca: si le doy un decimal en n_paraemters, entiende que es '% de varianza que quiero que se explique', si es un entero, limita la cantidad de componentes.
#
# ![image-5.png](attachment:image-5.png)
#
# q learning

# %% [markdown]
# ![image.png](attachment:image.png)
#
# no usa numpy ni listas, crea todo en la gpu

# %%
regularizacion l1, l2, tipos de regresion y clasificacion, teoria de las slides,
leer script de codigo y revisarlo,
